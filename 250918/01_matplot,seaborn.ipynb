# %%
# !pip install seaborn

# %%
import matplotlib.pyplot as plt 
import pandas as pd 
import numpy as np
import seaborn as sns
import platform

# %%
import ssl 
import certifi
ssl._create_default_https_context = \
    lambda: ssl.create_default_context(cafile=certifi.where())

# %%
# seaborn에서 샘플 데이터를 확인
iris_data = sns.load_dataset('iris')

# %%
pd.read_csv("../csv/iris.csv")

# %%
plt.boxplot(iris_data['sepal_width'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2809469f050>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x280968af490>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2809469ee10>],
#  'medians': [<matplotlib.lines.Line2D at 0x280968add50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x280968ad410>],
#  'means': []}

# %%
# matplot에 범례 추가 : legend()
# 보조선 추가 : grid()
# 그래프 제목 : title()
# x축, y축의 이름을 지정 : xlabel(), ylabel()
x = np.linspace(0, 10, 200)
x

# %%
y1 = np.sin(x)
y2 = np.cos(x)
plt.plot(x, y1, label='Sin')
plt.plot(x, y2, label='Cos')

# 그래프에 격자 추가
plt.grid(True, axis='both')
# x축과 y축의 이름을 생성
plt.xlabel('X')
plt.ylabel('Y')
# 그래프 제목 
plt.title('sin, cos graph')
# plt.legend(['Sin', 'Cos'])
# legend()에서 범례의 위치를 변경하는 매개변수는 loc
plt.legend(loc='upper left')

plt.show()

# %%
if platform.system() == 'Darwin':
    plt.rc('font', family='AppleGothic')
else:
    plt.rc('font', family='Malgun Gothic')

# %%
x = ['국어', '영어', '수학', '과학']
scores = [80, 60, 70, 50]

plt.bar(x, scores)

# x축의 데이터들을 회전 -> x축 데이터에 접근하는 함수 
plt.xticks(rotation=45)
# 그래프에 문자를 추가 (주석과는 다른 함수)
# text(x축, y축, 문자)
# plt.text(0, 80, '80')
for i in range(len(scores)):
    plt.text( i, scores[i]+1, scores[i] )

# %%
# 히스토그램 
datas = np.random.random(1000)
datas

# %%
# 히스토그램의 구간은 기본적으로 10개의 구간으로 생성

plt.hist(datas, bins=20)

plt.show()

# %%
# 산점도 그래프 scatter()

x = np.random.random(1000)
y = np.random.random(1000)
s_data = np.random.random(1000) * 300

# 그래프의 사이즈 변경
plt.figure(figsize=(10, 8))

plt.scatter(x, y, alpha=0.5, s=s_data, c='green')

plt.show()

# %%
iris_data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
plt.figure(figsize=(12, 8))
sns.scatterplot(data= iris_data, 
                x = 'sepal_length', 
                y='sepal_width', 
                hue = 'species')

plt.show()

# %%
# 박스 플롯 
plt.figure(figsize=(10, 6))

sns.boxplot( data = iris_data, x='species', y='petal_width' )

plt.show()

# %%
drinks = pd.read_csv("../csv/drinks.csv")
drinks.info()

# %%
corr = drinks.loc[:, 
                  'beer_servings' : \
                    'total_litres_of_pure_alcohol'].corr()

# %%
corr

# %%
plt.figure(figsize=(8, 5))
sns.heatmap(
    data = corr, 
    annot = True,   # 주석 표시 유무 
    square= True,   # 히트맵 정사각형 표시 유무
    fmt = '0.3f',   # 주석의 소수점 자리수 표시
    annot_kws= {'size' : 20}, # 주석의 환경 설정 폰트 크기 지정
    cbar = False,   # 색상 바를 표시 유무
    xticklabels= ['beer', 'spirit', 'wine', 'alcohol'], 
    yticklabels= ['beer', 'spirit', 'wine', 'alcohol']
)

plt.show()

# %%
sns.pairplot(
    data = drinks.loc[:, 
                      'beer_servings' : \
                        'total_litres_of_pure_alcohol'], 
    kind='reg'
)

plt.show()

# %%
# subplots() : 그래프가 그려지는 공간을 나눠서 여러개의 그래프를 그려주는 함수
# plt.subplot(2, 2, 1)
fig, axes = plt.subplots(2, 2)

# axes[0][0].plot([1,2,3,4])
# axes[1][1].plot([4,3,2,1])

axes.flat[3].plot([1,2,3,4])

plt.show()

# %%
cols = ['beer_servings', 'spirit_servings', 
        'wine_servings', 'total_litres_of_pure_alcohol']
fig, axes = plt.subplots(3, 1, figsize=(5, 15))

for i in range(1, len(cols)):
    ax = axes.flat[i-1]
    ax.scatter( drinks[cols[0]], drinks[cols[i]] )

plt.show()

# %%
np.random.seed(0)
df = pd.DataFrame(
    {
        'A' : np.random.random(10),
        'B' : np.random.random(10),
        'C' : np.random.random(10),
        'D' : np.random.random(10)
    }
)
df
# Out:
#           A         B         C         D
# 0  0.548814  0.791725  0.978618  0.264556
# 1  0.715189  0.528895  0.799159  0.774234
# 2  0.602763  0.568045  0.461479  0.456150
# 3  0.544883  0.925597  0.780529  0.568434
# 4  0.423655  0.071036  0.118274  0.018790
# 5  0.645894  0.087129  0.639921  0.617635
# 6  0.437587  0.020218  0.143353  0.612096
# 7  0.891773  0.832620  0.944669  0.616934
# 8  0.963663  0.778157  0.521848  0.943748
# 9  0.383442  0.870012  0.414662  0.681820

# %%
fig, axes = plt.subplots(2, 2, figsize = (10, 10))
col_num = 0
for i in range(2):
    for j in range(2):
        axes[i][j].plot(df.iloc[:,col_num])
        col_num += 1

# 그래프를 이미지 파일로 저장
fig.savefig('test.png')

plt.show()
